# %%
import pandas as pd 
from glob import glob 
import json 
import numpy as np

# %%
jsons = glob("*.json")

# %%
index = [str(item.split("_")[0]).upper() + " " +  str(item.split("_")[1]).upper() for item in jsons]
df = pd.DataFrame(data=np.zeros((11,5)),columns=["Original Mean CCC", "Tested Valence CCC", "Tested Arousal CCC", "Tested Dominance CCC", "Trained Mean CCC"],index=index)
df
# Out:
#               Original Mean CCC  Tested Valence CCC  Tested Arousal CCC  \
# CNN IEMOCAP                 0.0                 0.0                 0.0
# CNN IMPROV                  0.0                 0.0                 0.0
# CNN MIXED                   0.0                 0.0                 0.0
# LSTM IEMOCAP                0.0                 0.0                 0.0
# LSTM IMPROV                 0.0                 0.0                 0.0
# LSTM MIXED                  0.0                 0.0                 0.0
# MLP IEMOCAP                 0.0                 0.0                 0.0
# MLP IEMOCAP                 0.0                 0.0                 0.0
# MLP IMPROV                  0.0                 0.0                 0.0
# MLP IMPROV                  0.0                 0.0                 0.0
# MLP MIXED                   0.0                 0.0                 0.0
#
#               Tested Dominance CCC  Trained Mean CCC
# ...

# %%
for file in jsons:
    with open(file) as f:
        test_idx = int(jsons.index(file))
        data = json.load(f)
    df.at[index[test_idx],"Original Mean CCC"] = round(data["First Eval"],2)
    df.at[index[test_idx],"Tested Valence CCC"] = round(data["Second Eval whole"][0],2)
    df.at[index[test_idx],"Tested Arousal CCC"] = round(data["Second Eval whole"][1],2)
    df.at[index[test_idx],"Tested Dominance CCC"] = round(data["Second Eval whole"][1],2)
    df.at[index[test_idx],"Trained Mean CCC"] = round(data["Third Eval"],2)
df
# Out:
#               Original Mean CCC  Tested Valence CCC  Tested Arousal CCC  \
# CNN IEMOCAP                0.33                0.02                0.04
# CNN IMPROV                 0.37               -0.00               -0.00
# CNN MIXED                  0.20                0.03                0.05
# LSTM IEMOCAP               0.36                0.01               -0.00
# LSTM IMPROV                0.34               -0.00               -0.00
# LSTM MIXED                 0.22               -0.01               -0.00
# MLP IEMOCAP                0.43                0.04                0.02
# MLP IEMOCAP                0.43                0.04                0.02
# MLP IMPROV                 0.42                0.04               -0.06
# MLP IMPROV                 0.42                0.04               -0.06
# MLP MIXED                  0.29                0.10                0.05
#
#               Tested Dominance CCC  Trained Mean CCC
# ...

# %%
df.to_latex("OverallResults.tex")
